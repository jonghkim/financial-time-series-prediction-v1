# %% [markdown]
# # CNN Encoder LSTM Architecture

# %% [markdown]
# # The Simplest CNN Encoder + LSTM Model
# In this exercise we will apply time distributed 1D convolution on the sinusoidal time series and then apply lstm

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import math

import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate Noise Sin Values

# %%
def noisy_sin(steps_per_cycle = 50,
              number_of_cycles = 500,
              random_factor = 0.4):
  '''
  random_factor    : amont of noise in sign wave. 0 = no noise
  number_of_cycles : The number of steps required for one cycle

  Return : 
  pd.DataFrame() with column sin_t containing the generated sin wave 
  '''
  random.seed(0)
  df = pd.DataFrame(np.arange(steps_per_cycle * number_of_cycles + 1), columns=["t"])
  df["sin_t"] = df.t.apply(lambda x: math.sin(x * (2 * math.pi / steps_per_cycle)+ random.uniform(-1.0, +1.0) * random_factor))
  df["sin_t_clean"] = df.t.apply(lambda x: math.sin(x * (2 * math.pi / steps_per_cycle)))
  print("create period-{} sin wave with {} cycles".format(steps_per_cycle,number_of_cycles))
  print("In total, the sin wave time series length is {}".format(steps_per_cycle*number_of_cycles+1))
  return(df)

# %%
steps_per_cycle = 10

df = noisy_sin(steps_per_cycle=steps_per_cycle,
              random_factor = 0.2)

n_plot = 8
df[["sin_t"]].head(steps_per_cycle * n_plot).plot(
      title="Generated first {} cycles".format(n_plot),
      figsize=(15,3))
# Out:
# create period-10 sin wave with 500 cycles
# In total, the sin wave time series length is 5001

# %% [markdown]
# ### Split Train / Test Data

# %%
def _load_data(data, n_prev = 100):  
  """
  data should be pd.DataFrame()
  """

  docX, docY = [], []
  for i in range(len(data)-n_prev):
      docX.append(data.iloc[i:i+n_prev].as_matrix())
      docY.append(data.iloc[i+n_prev].as_matrix())
  alsX = np.array(docX)
  alsY = np.array(docY)

  return alsX, alsY

length_of_sequences = 10
test_size = 0.25

ntr = int(len(df) * (1 - test_size))

df_train = df[["sin_t"]].iloc[:ntr]
df_test  = df[["sin_t"]].iloc[ntr:]
(X_train, y_train) = _load_data(df_train, n_prev = length_of_sequences)
(X_test, y_test)   = _load_data(df_test, n_prev = length_of_sequences)  

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (3740, 10, 1) (3740, 1) (1241, 10, 1) (1241, 1)

# %% [markdown]
# ## Conv 1D + LSTM Model
# ### Build Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import LSTM

model = Sequential()

# Conv 1D will act like smoothing filter

model.add(Conv1D(filters=64, kernel_size=2, activation='relu', padding='same', input_shape=(10, 1)))

# Check that we do not use maxpooling here!

model.add(LSTM(32, return_sequences=False))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

model.compile(loss="mean_squared_error", optimizer="rmsprop")
  
## use the default values for batch_size, stateful
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 10, 64)            192
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 50)                1650
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 14,309
# Trainable params: 14,309
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train Model

# %%
hist = model.fit(X_train, y_train, batch_size=600, epochs=100, 
                 verbose=True,validation_split=0.05)
# Out:
# Train on 3553 samples, validate on 187 samples
# Epoch 1/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0145 - val_loss: 0.0095
# Epoch 2/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0099 - val_loss: 0.0118
# Epoch 3/100
# 3553/3553 [==============================] - 0s 93us/step - loss: 0.0112 - val_loss: 0.0177
# Epoch 4/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0129 - val_loss: 0.0094
# Epoch 5/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0092 - val_loss: 0.0099
# Epoch 6/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0145 - val_loss: 0.0132
# Epoch 7/100
# 3553/3553 [==============================] - 0s 92us/step - loss: 0.0103 - val_loss: 0.0091
# Epoch 8/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 9/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0109 - val_loss: 0.0172
# Epoch 10/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0119 - val_loss: 0.0114
# Epoch 11/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0105 - val_loss: 0.0129
# Epoch 12/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0110 - val_loss: 0.0103
# Epoch 13/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0111 - val_loss: 0.0129
# Epoch 14/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0103 - val_loss: 0.0130
# Epoch 15/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0127 - val_loss: 0.0107
# Epoch 16/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 17/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0097 - val_loss: 0.0114
# Epoch 18/100
# 3553/3553 [==============================] - 0s 92us/step - loss: 0.0111 - val_loss: 0.0138
# Epoch 19/100
# 3553/3553 [==============================] - 0s 85us/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 20/100
# 3553/3553 [==============================] - 0s 86us/step - loss: 0.0096 - val_loss: 0.0089
# Epoch 21/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0122 - val_loss: 0.0124
# Epoch 22/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0099 - val_loss: 0.0095
# Epoch 23/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 24/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0100 - val_loss: 0.0106
# Epoch 25/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0114 - val_loss: 0.0142
# Epoch 26/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0099 - val_loss: 0.0102
# Epoch 27/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 28/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 29/100
# 3553/3553 [==============================] - 0s 86us/step - loss: 0.0107 - val_loss: 0.0087
# Epoch 30/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0086 - val_loss: 0.0093
# Epoch 31/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 32/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0098 - val_loss: 0.0090
# Epoch 33/100
# 3553/3553 [==============================] - 0s 85us/step - loss: 0.0104 - val_loss: 0.0102
# Epoch 34/100
# 3553/3553 [==============================] - 0s 86us/step - loss: 0.0094 - val_loss: 0.0127
# Epoch 35/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0110 - val_loss: 0.0089
# Epoch 36/100
# 3553/3553 [==============================] - 0s 86us/step - loss: 0.0090 - val_loss: 0.0103
# Epoch 37/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0098 - val_loss: 0.0107
# Epoch 38/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 39/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 40/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 41/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0101 - val_loss: 0.0094
# Epoch 42/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0089 - val_loss: 0.0097
# Epoch 43/100
# 3553/3553 [==============================] - 0s 92us/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 44/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 45/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0095 - val_loss: 0.0125
# Epoch 46/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0105 - val_loss: 0.0120
# Epoch 47/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0093 - val_loss: 0.0089
# Epoch 48/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 49/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 50/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0091 - val_loss: 0.0126
# Epoch 51/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 52/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0097 - val_loss: 0.0101
# Epoch 53/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0099 - val_loss: 0.0091
# Epoch 54/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0088 - val_loss: 0.0143
# Epoch 55/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 56/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0099 - val_loss: 0.0103
# Epoch 57/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 58/100
# 3553/3553 [==============================] - 0s 93us/step - loss: 0.0101 - val_loss: 0.0090
# Epoch 59/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 60/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 61/100
# 3553/3553 [==============================] - 0s 92us/step - loss: 0.0093 - val_loss: 0.0094
# Epoch 62/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0094 - val_loss: 0.0107
# Epoch 63/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0091 - val_loss: 0.0100
# Epoch 64/100
# 3553/3553 [==============================] - 0s 93us/step - loss: 0.0096 - val_loss: 0.0104
# Epoch 65/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0086 - val_loss: 0.0102
# Epoch 66/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 67/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0089 - val_loss: 0.0088
# Epoch 68/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0096 - val_loss: 0.0106
# Epoch 69/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0091 - val_loss: 0.0098
# Epoch 70/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 71/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0090 - val_loss: 0.0118
# Epoch 72/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0098 - val_loss: 0.0108
# Epoch 73/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0101 - val_loss: 0.0088
# Epoch 74/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0081 - val_loss: 0.0096
# Epoch 75/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0097 - val_loss: 0.0095
# Epoch 76/100
# 3553/3553 [==============================] - 0s 86us/step - loss: 0.0092 - val_loss: 0.0098
# Epoch 77/100
# 3553/3553 [==============================] - 0s 86us/step - loss: 0.0100 - val_loss: 0.0093
# Epoch 78/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0083 - val_loss: 0.0101
# Epoch 79/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0098 - val_loss: 0.0096
# Epoch 80/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0084 - val_loss: 0.0093
# Epoch 81/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 82/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 83/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 84/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0093 - val_loss: 0.0097
# Epoch 85/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0090 - val_loss: 0.0121
# Epoch 86/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0102 - val_loss: 0.0087
# Epoch 87/100
# 3553/3553 [==============================] - 0s 92us/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 88/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 89/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0087 - val_loss: 0.0098
# Epoch 90/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0100 - val_loss: 0.0091
# Epoch 91/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0084 - val_loss: 0.0103
# Epoch 92/100
# 3553/3553 [==============================] - 0s 88us/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 93/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0089 - val_loss: 0.0097
# Epoch 94/100
# 3553/3553 [==============================] - 0s 87us/step - loss: 0.0093 - val_loss: 0.0098
# Epoch 95/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0087 - val_loss: 0.0118
# Epoch 96/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 97/100
# 3553/3553 [==============================] - 0s 90us/step - loss: 0.0087 - val_loss: 0.0097
# Epoch 98/100
# 3553/3553 [==============================] - 0s 89us/step - loss: 0.0102 - val_loss: 0.0098
# Epoch 99/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0087 - val_loss: 0.0097
# Epoch 100/100
# 3553/3553 [==============================] - 0s 91us/step - loss: 0.0086 - val_loss: 0.0088

# %%
for label in ["loss","val_loss"]:
    plt.plot(hist.history[label],label=label)

plt.ylabel("loss")
plt.xlabel("epoch")
plt.title("The final validation loss: {}".format(hist.history["val_loss"][-1]))
plt.legend()
plt.show()

# %% [markdown]
# ### Predict Model

# %%
y_pred = model.predict(X_test)
plt.figure(figsize=(19,3))

plt.plot(y_test[:100],label="true")
plt.plot(y_pred[:100],label="predicted")
plt.legend()
plt.show()
